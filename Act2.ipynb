# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga desde un archivo .xlsx sin indice
data = pd.read_excel('Inmuebles2.xlsx')

# %%
#Convertir DataFrame a CSV
data.to_csv("Inmuebles2.csv")
data
# Out:
#      Esta es una base de datos que describe las operaciones inmobiliarias de una empresa  \
# 0                                            Referencia
# 1                                                     1
# 2                                                     2
# 3                                                     3
# 4                                                     4
# ...                                                 ...
# 3333                                               3333
# 3334                                               3334
# 3335                                               3335
# 3336                                               3336
# 3337                                               3337
#
#                Unnamed: 1  Unnamed: 2 Unnamed: 3 Unnamed: 4  Unnamed: 5  \
# 0              Fecha Alta        Tipo  Operación  Provincia  Superficie
# 1     2004-01-01 00:00:00     Parking   Alquiler     Lleida         291
# ...

# %%
#Eliminar primera fila o filas innecesarias
#Se elimina la primera fila que contenia información y solo nos quedamos con las etiquetas de cada columna
data= pd.read_csv('Inmuebles2.csv', skiprows=1, low_memory=False)
data
# Out:
#          0  Referencia           Fecha Alta        Tipo Operación  Provincia  \
# 0        1           1  2004-01-01 00:00:00     Parking  Alquiler     Lleida
# 1        2           2  2004-01-01 00:00:00       Local     Venta     Girona
# 2        3           3  2004-01-01 00:00:00     Oficina  Alquiler     Girona
# 3        4           4  2004-01-02 00:00:00     Parking  Alquiler     Girona
# 4        5           5  2004-01-02 00:00:00       Suelo     Venta  Tarragona
# ...    ...         ...                  ...         ...       ...        ...
# 3332  3333        3333  2007-04-29 00:00:00  Industrial  Alquiler     Lleida
# 3333  3334        3334  2007-04-29 00:00:00        Piso  Alquiler     Girona
# 3334  3335        3335  2007-04-30 00:00:00       Suelo     Venta  Tarragona
# 3335  3336        3336  2007-04-30 00:00:00        Piso  Alquiler  Barcelona
# 3336  3337        3337  2007-04-30 00:00:00     Parking     Venta     Lleida
#
# ...

# %%
#Eliminamos las columnas inecesarias que contienen los mismos datos "0" y "Referencias"
#Quedamos con 8 columnas
data= data.drop(['0','Referencia'], axis=1)
data
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida         NaN
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# ...

# %%
#Identificar valores nulos
#Vemos que tenemos valores nulos en todas nuestras columnas
valores_nulos=data.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        2
# Tipo              2
# Operación         1
# Provincia         4
# Superficie        4
# Precio Venta      6
# Fecha Venta     578
# Vendedor        578
# dtype: int64

# %%
#Se copia el Dataframe
data2=data.copy()

# %%
#Sustituir valores nulos con promedio o media (Precio Venta)
data2["Precio Venta"]=data2["Precio Venta"].fillna(round(data["Precio Venta"].mean(),1))
data2
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida         NaN
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        2
# Tipo              2
# Operación         1
# Provincia         4
# Superficie        4
# Precio Venta      0
# Fecha Venta     578
# Vendedor        578
# dtype: int64

# %%
#Sustituir valores nulos con mediana
#Superficie
data2["Superficie"]=data2["Superficie"].fillna(round(data["Superficie"].median(),1))
data2
# Out:
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3332  2007-04-29 00:00:00  Industrial  Alquiler     Lleida       221.0
# 3333  2007-04-29 00:00:00        Piso  Alquiler     Girona        55.0
# 3334  2007-04-30 00:00:00       Suelo     Venta  Tarragona        78.0
# 3335  2007-04-30 00:00:00        Piso  Alquiler  Barcelona        88.0
# 3336  2007-04-30 00:00:00     Parking     Venta     Lleida       170.0
#
#       Precio Venta          Fecha Venta Vendedor
# 0        2133903.0  2004-06-19 00:00:00   Carmen
# ...

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        2
# Tipo              2
# Operación         1
# Provincia         4
# Superficie        0
# Precio Venta      0
# Fecha Venta     578
# Vendedor        578
# dtype: int64

# %%
#Sustituir valores nulos hacia adelante
#Filtro por columnas

data2['Fecha Alta'] = data2['Fecha Alta'].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        0
# Tipo              2
# Operación         1
# Provincia         4
# Superficie        0
# Precio Venta      0
# Fecha Venta     578
# Vendedor        578
# dtype: int64

# %%
#Sustituir valores nulos hacia atras
data2['Provincia'] = data2['Provincia'].fillna(method="bfill")

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        0
# Tipo              2
# Operación         1
# Provincia         0
# Superficie        0
# Precio Venta      0
# Fecha Venta     578
# Vendedor        578
# dtype: int64

# %%
#Sustituir por un dato concreto
data2['Tipo'] = data2['Tipo'].fillna("Piso")

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        0
# Tipo              0
# Operación         1
# Provincia         0
# Superficie        0
# Precio Venta      0
# Fecha Venta     578
# Vendedor        578
# dtype: int64

# %%
#Sustituir valores hacia adelante
data2['Operación'] = data2['Operación'].fillna(method="ffill")

# %%
#Corroboramos valores nulos
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# Fecha Alta        0
# Tipo              0
# Operación         0
# Provincia         0
# Superficie        0
# Precio Venta      0
# Fecha Venta     578
# Vendedor        578
# dtype: int64

# %%
#Se eliminan los valores nulos restantes
#Eliminamos filas con nulos
data3= data2.dropna(0)
data3
# Out:
# /var/folders/s5/9tn200911wjfzyc3b8q58s900000gn/T/ipykernel_25104/3060994295.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   data3= data2.dropna(0)
#                Fecha Alta        Tipo Operación  Provincia  Superficie  \
# 0     2004-01-01 00:00:00     Parking  Alquiler     Lleida       291.0
# 1     2004-01-01 00:00:00       Local     Venta     Girona       185.0
# 2     2004-01-01 00:00:00     Oficina  Alquiler     Girona        82.0
# 3     2004-01-02 00:00:00     Parking  Alquiler     Girona       285.0
# 4     2004-01-02 00:00:00       Suelo     Venta  Tarragona       152.0
# ...                   ...         ...       ...        ...         ...
# 3016  2006-12-30 00:00:00        Casa  Alquiler  Barcelona       264.0
# 3017  2006-12-31 00:00:00     Oficina     Venta     Lleida        69.0
# 3030  2007-01-07 00:00:00  Industrial  Alquiler     Lleida       196.0
# ...

# %%
#Se verifica que ya no existan nulos
valores_nulos=data3.isnull().sum()
valores_nulos
# Out:
# Fecha Alta      0
# Tipo            0
# Operación       0
# Provincia       0
# Superficie      0
# Precio Venta    0
# Fecha Venta     0
# Vendedor        0
# dtype: int64

# %%
#Histograma 1, variable 'Superficie'
plt.hist(x=data3["Superficie"], color='blue', rwidth=0.50)
plt.title('Histograma de Superficies')
plt.xlabel('Superficies')
plt.ylabel('Frecuencia')
plt.show()

# %%
#Histograma 2, variable 'Precio Venta'
plt.hist(x=data3["Precio Venta"], color='red', rwidth=0.50)
plt.title('Histograma de Precio Venta')
plt.xlabel('Precio Venta')
plt.ylabel('Frecuencia')
plt.show()

# %%
data3.to_csv("Inmuebles_Final.csv")
